# %% [markdown]
# # Galaxy clusters in Euclid Q1
#
# **AAS workshop:** *Euclid Data in the Cloud - Access, Analysis, and Science Opportunities* (90 min)
#
# _Notebook 2 of 3._ This notebook uses the data-access patterns from `01_Euclid_data_cloud.ipynb` (TAP, SIA/IBE, direct S3) to find and inspect galaxy clusters in the Q1 release.
#
# Notebook 3 (`03_Euclid_AGN_assignment.ipynb`) is the hands-on assignment that applies the same toolkit to AGN selection.

# %% [markdown]
# ## Outline (to be filled in)
#
# 1. The Q1 cluster catalogs — what's released, by which detection method.
# 2. Selecting a cluster sample with TAP.
# 3. Member galaxies and red-sequence inspection.
# 4. Imaging — multi-band cutouts of one cluster from IBE.
# 5. (Optional) Stacking, profiles, or a richness-mass comparison.
